# %% [markdown]
# <a href="https://colab.research.google.com/github/salsadewinta/APKWLaundry.github.io/blob/main/Pertemuan_2_Data_Analyst.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **1. Importing Library**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns
from wordcloud import WordCloud

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns
from wordcloud import WordCloud

# %%
# Read Dataset
data = pd.read_csv('/content/drive/MyDrive/Bismillah LIGHT UP RAMADHAN/DataAnalyst.csv')
data.head()
# Out:
#    Unnamed: 0                                          Job Title  \
# 0           0  Data Analyst, Center on Immigration and Justic...
# 1           1                               Quality Data Analyst
# 2           2  Senior Data Analyst, Insights & Analytics Team...
# 3           3                                       Data Analyst
# 4           4                             Reporting Data Analyst
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
# 3  $37K-$66K (Glassdoor est.)
# 4  $37K-$66K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
#
#                               Company Name      Location  Headquarters  \
# 0           Vera Institute of Justice\n3.2  New York, NY  New York, NY
# 1  Visiting Nurse Service of New York\n3.8  New York, NY  New York, NY
# 2                         Squarespace\n3.4  New York, NY  New York, NY
# 3                            Celerity\n4.1  New York, NY    McLean, VA
# 4                             FanDuel\n3.9  New York, NY  New York, NY
#
#                      Size  Founded               Type of ownership  \
# 0    201 to 500 employees     1961          Nonprofit Organization
# 1        10000+ employees     1893          Nonprofit Organization
# 2  1001 to 5000 employees     2003               Company - Private
# 3    201 to 500 employees     2002  Subsidiary or Business Segment
# 4   501 to 1000 employees     2009               Company - Private
#
#                            Industry                            Sector  \
# 0                 Social Assistance                        Non-Profit
# 1  Health Care Services & Hospitals                       Health Care
# 2                          Internet            Information Technology
# 3                       IT Services            Information Technology
# 4               Sports & Recreation  Arts, Entertainment & Recreation
#
#                       Revenue Competitors Easy Apply
# 0  $100 to $500 million (USD)          -1       True
# 1      $2 to $5 billion (USD)          -1         -1
# 2    Unknown / Non-Applicable     GoDaddy         -1
# 3   $50 to $100 million (USD)          -1         -1
# 4  $100 to $500 million (USD)  DraftKings       True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **2. Data Cleaning**

# %%
# Drop Kolom yang gak penting
data.drop(['Unnamed: 0'], axis=1,inplace=True)

# %%
data
# Out:
#                                               Job Title  \
# 0     Data Analyst, Center on Immigration and Justic...
# 1                                  Quality Data Analyst
# 2     Senior Data Analyst, Insights & Analytics Team...
# 3                                          Data Analyst
# 4                                Reporting Data Analyst
# ...                                                 ...
# 2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249              Senior Data Analyst (Corporate Audit)
# 2250  Technical Business Analyst (SQL, Data analytic...
# 2251                Data Analyst 3, Customer Experience
# 2252                        Senior Quality Data Analyst
#
#                   Salary Estimate  \
# 0      $37K-$66K (Glassdoor est.)
# 1      $37K-$66K (Glassdoor est.)
# 2      $37K-$66K (Glassdoor est.)
# 3      $37K-$66K (Glassdoor est.)
# 4      $37K-$66K (Glassdoor est.)
# ...                           ...
# 2248  $78K-$104K (Glassdoor est.)
# 2249  $78K-$104K (Glassdoor est.)
# 2250  $78K-$104K (Glassdoor est.)
# 2251  $78K-$104K (Glassdoor est.)
# 2252  $78K-$104K (Glassdoor est.)
#
#                                         Job Description  Rating  \
# 0     Are you eager to roll up your sleeves and harn...     3.2
# 1     Overview\n\nProvides analytical and technical ...     3.8
# 2     We’re looking for a Senior Data Analyst who ha...     3.4
# 3     Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4     ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
# ...                                                 ...     ...
# 2248  Maintains systems to protect data from unautho...     2.5
# 2249  Position:\nSenior Data Analyst (Corporate Audi...     2.9
# 2250  Title: Technical Business Analyst (SQL, Data a...    -1.0
# 2251  Summary\n\nResponsible for working cross-funct...     3.1
# 2252  You.\n\nYou bring your body, mind, heart and s...     3.4
#
#                                  Company Name        Location  \
# 0              Vera Institute of Justice\n3.2    New York, NY
# 1     Visiting Nurse Service of New York\n3.8    New York, NY
# 2                            Squarespace\n3.4    New York, NY
# 3                               Celerity\n4.1    New York, NY
# 4                                FanDuel\n3.9    New York, NY
# ...                                       ...             ...
# 2248                       Avacend, Inc.\n2.5      Denver, CO
# 2249                   Arrow Electronics\n2.9  Centennial, CO
# 2250                                 Spiceorb      Denver, CO
# 2251         Contingent Network Services\n3.1  Centennial, CO
# 2252                          SCL Health\n3.4  Broomfield, CO
#
#           Headquarters                    Size  Founded  \
# 0         New York, NY    201 to 500 employees     1961
# 1         New York, NY        10000+ employees     1893
# 2         New York, NY  1001 to 5000 employees     2003
# 3           McLean, VA    201 to 500 employees     2002
# 4         New York, NY   501 to 1000 employees     2009
# ...                ...                     ...      ...
# 2248    Alpharetta, GA     51 to 200 employees       -1
# 2249    Centennial, CO        10000+ employees     1935
# 2250                -1                      -1       -1
# 2251  West Chester, OH    201 to 500 employees     1984
# 2252    Broomfield, CO        10000+ employees     1864
#
#                    Type of ownership                                 Industry  \
# 0             Nonprofit Organization                        Social Assistance
# 1             Nonprofit Organization         Health Care Services & Hospitals
# 2                  Company - Private                                 Internet
# 3     Subsidiary or Business Segment                              IT Services
# 4                  Company - Private                      Sports & Recreation
# ...                              ...                                      ...
# 2248               Company - Private                   Staffing & Outsourcing
# 2249                Company - Public                                Wholesale
# 2250                              -1                                       -1
# 2251               Company - Private  Enterprise Software & Network Solutions
# 2252          Nonprofit Organization         Health Care Services & Hospitals
#
#                                 Sector                     Revenue  \
# 0                           Non-Profit  $100 to $500 million (USD)
# 1                          Health Care      $2 to $5 billion (USD)
# 2               Information Technology    Unknown / Non-Applicable
# 3               Information Technology   $50 to $100 million (USD)
# 4     Arts, Entertainment & Recreation  $100 to $500 million (USD)
# ...                                ...                         ...
# 2248                 Business Services    Unknown / Non-Applicable
# 2249                 Business Services          $10+ billion (USD)
# 2250                                -1                          -1
# 2251            Information Technology    $25 to $50 million (USD)
# 2252                       Health Care      $2 to $5 billion (USD)
#
#                                             Competitors Easy Apply
# 0                                                    -1       True
# 1                                                    -1         -1
# 2                                               GoDaddy         -1
# 3                                                    -1         -1
# 4                                            DraftKings       True
# ...                                                 ...        ...
# 2248                                                 -1         -1
# 2249                     Avnet, Ingram Micro, Tech Data         -1
# 2250                                                 -1         -1
# 2251                                                 -1         -1
# 2252  Centura Health, HealthONE, Denver Health and H...         -1
#
# [2253 rows x 15 columns]

# %%
# Fungsi untuk Cek Missing Values
def missing_values_table(df):
        # Total missing values
        mis_val = df.isnull().sum()

        # Percentage of missing values
        mis_val_percent = 100 * df.isnull().sum() / len(df)

        # Make a table with the results
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)

        # Rename the columns
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})

        # Sort the table by percentage of missing descending
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)

        # Print some summary information
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"
            "There are " + str(mis_val_table_ren_columns.shape[0]) +
              " columns that have missing values.")

        # Return the dataframe with missing information
        return mis_val_table_ren_columns

# %%
missing_values_table(data)
# Out:
# Your selected dataframe has 15 columns.
# There are 1 columns that have missing values.
#               Missing Values  % of Total Values
# Company Name               1                0.0

# %% [markdown]
# kita dapat dengan cepat melihat perbandingan jumlah data antara nilai yang berbeda dalam kolom 'Easy Apply', yang berguna untuk mendapatkan pemahaman awal tentang bagaimana data terdistribusi dalam kolom tersebut.

# %%
# Untuk melihat perbandingan data di kolom easy apply
data['Location'].value_counts()
# Out:
# New York, NY         310
# Chicago, IL          130
# San Francisco, CA    119
# Austin, TX            81
# Los Angeles, CA       80
#                     ...
# Carrollton, TX         1
# Tarrant, TX            1
# Addison, TX            1
# Burr Ridge, IL         1
# Littleton, CO          1
# Name: Location, Length: 253, dtype: int64

# %%
# Untuk melihat perbandingan data di kolom competitors
data['Competitors'].value_counts()
# Out:
# -1                                                                 1732
# Robert Half, Insight Global                                          14
# Adecco, Manpower                                                     14
# Artech Information Systems, Mindlance, Tech Mahindra                 10
# Google, Microsoft, Samsung Electronics                               10
#                                                                    ...
# Carr Riggs & Ingram, Cherry Bekaert, LBMC                             1
# Transnational Foods, One Source Distributors                          1
# GE                                                                    1
# Fiserv, First Data, Jack Henry & Associates                           1
# Centura Health, HealthONE, Denver Health and Hospital Authority       1
# Name: Competitors, Length: 291, dtype: int64

# %%
# Untuk melihat perbandingan data di kolom rating
data['Rating'].value_counts()[:5]
# Out:
# -1.0    272
#  3.9    140
#  3.6    135
#  3.7    132
#  5.0    131
# Name: Rating, dtype: int64

# %% [markdown]
# Karena beberapa kolom berisi -1 atau '-1.0' atau '-1' dll. Kita perlu membersihkan ini (Ini semacam nilai nol)

# %%
# Membuang data dengan rating yang dibawah 0
data=data.replace(-1,np.nan)
data=data.replace(-1.0,np.nan)
data=data.replace('-1',np.nan)

# %%
# Out:
#                                               Job Title  \
# 0     Data Analyst, Center on Immigration and Justic...
# 1                                  Quality Data Analyst
# 2     Senior Data Analyst, Insights & Analytics Team...
# 3                                          Data Analyst
# 4                                Reporting Data Analyst
# ...                                                 ...
# 2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249              Senior Data Analyst (Corporate Audit)
# 2250  Technical Business Analyst (SQL, Data analytic...
# 2251                Data Analyst 3, Customer Experience
# 2252                        Senior Quality Data Analyst
#
#                   Salary Estimate  \
# 0      $37K-$66K (Glassdoor est.)
# 1      $37K-$66K (Glassdoor est.)
# 2      $37K-$66K (Glassdoor est.)
# 3      $37K-$66K (Glassdoor est.)
# 4      $37K-$66K (Glassdoor est.)
# ...                           ...
# 2248  $78K-$104K (Glassdoor est.)
# 2249  $78K-$104K (Glassdoor est.)
# 2250  $78K-$104K (Glassdoor est.)
# 2251  $78K-$104K (Glassdoor est.)
# 2252  $78K-$104K (Glassdoor est.)
#
#                                         Job Description  Rating  \
# 0     Are you eager to roll up your sleeves and harn...     3.2
# 1     Overview\n\nProvides analytical and technical ...     3.8
# 2     We’re looking for a Senior Data Analyst who ha...     3.4
# 3     Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4     ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
# ...                                                 ...     ...
# 2248  Maintains systems to protect data from unautho...     2.5
# 2249  Position:\nSenior Data Analyst (Corporate Audi...     2.9
# 2250  Title: Technical Business Analyst (SQL, Data a...     NaN
# 2251  Summary\n\nResponsible for working cross-funct...     3.1
# 2252  You.\n\nYou bring your body, mind, heart and s...     3.4
#
#                                  Company Name        Location  \
# 0              Vera Institute of Justice\n3.2    New York, NY
# 1     Visiting Nurse Service of New York\n3.8    New York, NY
# 2                            Squarespace\n3.4    New York, NY
# 3                               Celerity\n4.1    New York, NY
# 4                                FanDuel\n3.9    New York, NY
# ...                                       ...             ...
# 2248                       Avacend, Inc.\n2.5      Denver, CO
# 2249                   Arrow Electronics\n2.9  Centennial, CO
# 2250                                 Spiceorb      Denver, CO
# 2251         Contingent Network Services\n3.1  Centennial, CO
# 2252                          SCL Health\n3.4  Broomfield, CO
#
#           Headquarters                    Size  Founded  \
# 0         New York, NY    201 to 500 employees   1961.0
# 1         New York, NY        10000+ employees   1893.0
# 2         New York, NY  1001 to 5000 employees   2003.0
# 3           McLean, VA    201 to 500 employees   2002.0
# 4         New York, NY   501 to 1000 employees   2009.0
# ...                ...                     ...      ...
# 2248    Alpharetta, GA     51 to 200 employees      NaN
# 2249    Centennial, CO        10000+ employees   1935.0
# 2250               NaN                     NaN      NaN
# 2251  West Chester, OH    201 to 500 employees   1984.0
# 2252    Broomfield, CO        10000+ employees   1864.0
#
#                    Type of ownership                                 Industry  \
# 0             Nonprofit Organization                        Social Assistance
# 1             Nonprofit Organization         Health Care Services & Hospitals
# 2                  Company - Private                                 Internet
# 3     Subsidiary or Business Segment                              IT Services
# 4                  Company - Private                      Sports & Recreation
# ...                              ...                                      ...
# 2248               Company - Private                   Staffing & Outsourcing
# 2249                Company - Public                                Wholesale
# 2250                             NaN                                      NaN
# 2251               Company - Private  Enterprise Software & Network Solutions
# 2252          Nonprofit Organization         Health Care Services & Hospitals
#
#                                 Sector                     Revenue  \
# 0                           Non-Profit  $100 to $500 million (USD)
# 1                          Health Care      $2 to $5 billion (USD)
# 2               Information Technology    Unknown / Non-Applicable
# 3               Information Technology   $50 to $100 million (USD)
# 4     Arts, Entertainment & Recreation  $100 to $500 million (USD)
# ...                                ...                         ...
# 2248                 Business Services    Unknown / Non-Applicable
# 2249                 Business Services          $10+ billion (USD)
# 2250                               NaN                         NaN
# 2251            Information Technology    $25 to $50 million (USD)
# 2252                       Health Care      $2 to $5 billion (USD)
#
#                                             Competitors Easy Apply
# 0                                                   NaN       True
# 1                                                   NaN        NaN
# 2                                               GoDaddy        NaN
# 3                                                   NaN        NaN
# 4                                            DraftKings       True
# ...                                                 ...        ...
# 2248                                                NaN        NaN
# 2249                     Avnet, Ingram Micro, Tech Data        NaN
# 2250                                                NaN        NaN
# 2251                                                NaN        NaN
# 2252  Centura Health, HealthONE, Denver Health and H...        NaN
#
# [2253 rows x 15 columns]

# %%
missing_values_table(data)
# Out:
# Your selected dataframe has 15 columns.
# There are 12 columns that have missing values.
#                    Missing Values  % of Total Values
# Easy Apply                   2173               96.4
# Competitors                  1732               76.9
# Founded                       660               29.3
# Industry                      353               15.7
# Sector                        353               15.7
# Rating                        272               12.1
# Headquarters                  172                7.6
# Size                          163                7.2
# Type of ownership             163                7.2
# Revenue                       163                7.2
# Salary Estimate                 1                0.0
# Company Name                    1                0.0

# %% [markdown]
# Sekarang Anda dapat melihat ada banyak nilai yang hilang dalam kumpulan data. 'Lamar Mudah' dan 'Pesaing' memiliki jumlah nilai yang hilang maksimum (> 50%). Sebagian besar perusahaan memiliki nilai nol dalam lamaran yang mudah karena mereka tidak merekrut.

# %%
data['Company Name'],_=data['Company Name'].str.split('\n', 1).str
# Out:
# <ipython-input-13-d79831fb4d01>:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   data['Company Name'],_=data['Company Name'].str.split('\n', 1).str
# <ipython-input-13-d79831fb4d01>:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   data['Company Name'],_=data['Company Name'].str.split('\n', 1).str

# %%
data['Job Title'],data['Department']=data['Job Title'].str.split(',', 1).str
# Out:
# <ipython-input-14-2485459de680>:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   data['Job Title'],data['Department']=data['Job Title'].str.split(',', 1).str
# <ipython-input-14-2485459de680>:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   data['Job Title'],data['Department']=data['Job Title'].str.split(',', 1).str

# %%
data['Salary Estimate'],_=data['Salary Estimate'].str.split('(', 1).str
# Out:
# <ipython-input-15-db56586e1189>:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   data['Salary Estimate'],_=data['Salary Estimate'].str.split('(', 1).str
# <ipython-input-15-db56586e1189>:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   data['Salary Estimate'],_=data['Salary Estimate'].str.split('(', 1).str

# %%
data['Min_Salary'],data['Max_Salary']=data['Salary Estimate'].str.split('-').str
data['Min_Salary']=data['Min_Salary'].str.strip(' ').str.lstrip('$').str.rstrip('K').fillna(0).astype('int')
data['Max_Salary']=data['Max_Salary'].str.strip(' ').str.lstrip('$').str.rstrip('K').fillna(0).astype('int')
# Out:
# <ipython-input-16-459ba913a5e5>:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   data['Min_Salary'],data['Max_Salary']=data['Salary Estimate'].str.split('-').str

# %%
data.drop(['Salary Estimate'],axis=1,inplace=True)

# %%
data
# Out:
#                                               Job Title  \
# 0                                          Data Analyst
# 1                                  Quality Data Analyst
# 2                                   Senior Data Analyst
# 3                                          Data Analyst
# 4                                Reporting Data Analyst
# ...                                                 ...
# 2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249              Senior Data Analyst (Corporate Audit)
# 2250                    Technical Business Analyst (SQL
# 2251                                     Data Analyst 3
# 2252                        Senior Quality Data Analyst
#
#                                         Job Description  Rating  \
# 0     Are you eager to roll up your sleeves and harn...     3.2
# 1     Overview\n\nProvides analytical and technical ...     3.8
# 2     We’re looking for a Senior Data Analyst who ha...     3.4
# 3     Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4     ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
# ...                                                 ...     ...
# 2248  Maintains systems to protect data from unautho...     2.5
# 2249  Position:\nSenior Data Analyst (Corporate Audi...     2.9
# 2250  Title: Technical Business Analyst (SQL, Data a...     NaN
# 2251  Summary\n\nResponsible for working cross-funct...     3.1
# 2252  You.\n\nYou bring your body, mind, heart and s...     3.4
#
#                             Company Name        Location      Headquarters  \
# 0              Vera Institute of Justice    New York, NY      New York, NY
# 1     Visiting Nurse Service of New York    New York, NY      New York, NY
# 2                            Squarespace    New York, NY      New York, NY
# 3                               Celerity    New York, NY        McLean, VA
# 4                                FanDuel    New York, NY      New York, NY
# ...                                  ...             ...               ...
# 2248                       Avacend, Inc.      Denver, CO    Alpharetta, GA
# 2249                   Arrow Electronics  Centennial, CO    Centennial, CO
# 2250                            Spiceorb      Denver, CO               NaN
# 2251         Contingent Network Services  Centennial, CO  West Chester, OH
# 2252                          SCL Health  Broomfield, CO    Broomfield, CO
#
#                         Size  Founded               Type of ownership  \
# 0       201 to 500 employees   1961.0          Nonprofit Organization
# 1           10000+ employees   1893.0          Nonprofit Organization
# 2     1001 to 5000 employees   2003.0               Company - Private
# 3       201 to 500 employees   2002.0  Subsidiary or Business Segment
# 4      501 to 1000 employees   2009.0               Company - Private
# ...                      ...      ...                             ...
# 2248     51 to 200 employees      NaN               Company - Private
# 2249        10000+ employees   1935.0                Company - Public
# 2250                     NaN      NaN                             NaN
# 2251    201 to 500 employees   1984.0               Company - Private
# 2252        10000+ employees   1864.0          Nonprofit Organization
#
#                                      Industry  \
# 0                           Social Assistance
# 1            Health Care Services & Hospitals
# 2                                    Internet
# 3                                 IT Services
# 4                         Sports & Recreation
# ...                                       ...
# 2248                   Staffing & Outsourcing
# 2249                                Wholesale
# 2250                                      NaN
# 2251  Enterprise Software & Network Solutions
# 2252         Health Care Services & Hospitals
#
#                                 Sector                     Revenue  \
# 0                           Non-Profit  $100 to $500 million (USD)
# 1                          Health Care      $2 to $5 billion (USD)
# 2               Information Technology    Unknown / Non-Applicable
# 3               Information Technology   $50 to $100 million (USD)
# 4     Arts, Entertainment & Recreation  $100 to $500 million (USD)
# ...                                ...                         ...
# 2248                 Business Services    Unknown / Non-Applicable
# 2249                 Business Services          $10+ billion (USD)
# 2250                               NaN                         NaN
# 2251            Information Technology    $25 to $50 million (USD)
# 2252                       Health Care      $2 to $5 billion (USD)
#
#                                             Competitors Easy Apply  \
# 0                                                   NaN       True
# 1                                                   NaN        NaN
# 2                                               GoDaddy        NaN
# 3                                                   NaN        NaN
# 4                                            DraftKings       True
# ...                                                 ...        ...
# 2248                                                NaN        NaN
# 2249                     Avnet, Ingram Micro, Tech Data        NaN
# 2250                                                NaN        NaN
# 2251                                                NaN        NaN
# 2252  Centura Health, HealthONE, Denver Health and H...        NaN
#
#                                             Department  Min_Salary  Max_Salary
# 0              Center on Immigration and Justice (CIJ)          37          66
# 1                                                  NaN          37          66
# 2      Insights & Analytics Team [Customer Operations]          37          66
# 3                                                  NaN          37          66
# 4                                                  NaN          37          66
# ...                                                ...         ...         ...
# 2248                                               NaN          78         104
# 2249                                               NaN          78         104
# 2250                              Data analytics, ETL)          78         104
# 2251                               Customer Experience          78         104
# 2252                                               NaN          78         104
#
# [2253 rows x 17 columns]

# %% [markdown]
# ## **3. Data Visualization**

# %% [markdown]
# ### 3.1. Current Openings

# %%
data['Easy Apply']=data['Easy Apply'].fillna(False).astype('bool')

# %%
data['Easy Apply']
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 2248    False
# 2249    False
# 2250    False
# 2251    False
# 2252    False
# Name: Easy Apply, Length: 2253, dtype: bool

# %%
df_easy_apply=data[data['Easy Apply']==True]
df=df_easy_apply.groupby('Company Name')['Easy Apply'].count().reset_index()
company_opening_df=df.sort_values('Easy Apply',ascending=False).head(10)

# %%
plt.figure(figsize=(10,5))
chart = sns.barplot(
    data=company_opening_df,
    x='Company Name',
    y='Easy Apply',
    palette='Set1'
)
chart=chart.set_xticklabels(
    chart.get_xticklabels(),
    rotation=65,
    horizontalalignment='right',
    fontweight='light',
)

# %% [markdown]
# ### 3.2. Salary Distribution of Data Analyst

# %% [markdown]
# ni merencanakan histogram dan perkiraan kepadatan kernel untuk gaji minimum dan maksimum analis data. Ini dimulai dengan memfilter data agar hanya menyertakan baris dengan jabatan 'Analis Data'. Kemudian, ia menentukan gaya dan palet plot menggunakan perpustakaan seaborn. Ini menciptakan gambar dengan dua subplot, masing-masing mewakili distribusi gaji minimum dan maksimum. Fungsi seaborn.distplot digunakan untuk memplot histogram dan estimasi kepadatan kernel. Terakhir, beberapa penyesuaian format dilakukan dan tata letak diperketat.

# %%
data_analyst = data[data['Job Title']=='Data Analyst']

sns.set(style="white", palette="muted", color_codes=True)
f, axes = plt.subplots(1, 2, figsize=(15, 8), sharex=True)
sns.despine(left=True)

#Plot a histogram and kernel density estimate
sns.distplot(data_analyst['Min_Salary'], color="b", ax=axes[0])
sns.distplot(data_analyst['Max_Salary'], color="r",ax=axes[1])
plt.setp(axes, yticks=[])
plt.tight_layout()
# Out:
# <ipython-input-19-180a53ed23af>:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_analyst['Min_Salary'], color="b", ax=axes[0])
# <ipython-input-19-180a53ed23af>:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_analyst['Max_Salary'], color="r",ax=axes[1])

# %% [markdown]
# ### 3.3. Top 20 cities with their minimum and maximum salaries

# %%
df=data.groupby('Location')[['Max_Salary','Min_Salary']].mean().sort_values(['Max_Salary','Min_Salary'],ascending=False).head(20)

# %% [markdown]
# Fungsi sort_values digunakan untuk mengurutkan nilai-nilai dalam suatu DataFrame atau Series berdasarkan nilai kolom tertentu. Dengan menggunakan fungsi ini, kita dapat mengurutkan data berdasarkan kolom yang ingin kita gunakan sebagai acuan pengurutan. Nilai-nilai dalam kolom tersebut akan diurutkan secara menaik atau menurun, tergantung pada parameter yang kita tentukan.

# %%
fig = go.Figure()

fig.add_trace(go.Bar(x=df.index,y=df['Min_Salary'],name='Minimum salary'))
fig.add_trace(go.Bar(x=df.index,y=df['Max_Salary'],name='Maximum Salary'))

fig.update_layout(title='Top 20 cities with their minimum and maximum salaries',barmode='stack')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a3b59095-e145-4d94-8162-12a11249c564" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a3b59095-e145-4d94-8162-12a11249c564")) {                    Plotly.newPlot(                        "a3b59095-e145-4d94-8162-12a11249c564",                        [{"name":"Minimum salary","x":["Newark, CA","Daly City, CA","Marin City, CA","Los Gatos, CA","Berkeley, CA","San Jose, CA","Cupertino, CA","Santa Clara, CA","Pico Rivera, CA","Whittier, CA","Far Rockaway, NY","Secaucus, NJ","Sunnyvale, CA","Menlo Park, CA","Elk Grove Village, IL","Glenview, IL","Maywood, IL","Northfield, IL","Stanford, CA","San Francisco, CA"],"y":[110.0,93.0,93.0,89.33333333333333,82.0,79.42105263157895,77.76923076923077,76.18181818181819,113.0,113.0,77.0,77.0,75.0,74.27272727272727,97.0,97.0,97.0,97.0,69.0,72.52100840336135],"type":"bar"},{"name":"Maximum Salary","x":["Newark, CA","Daly City, CA","Marin City, CA","Los Gatos, CA","Berkeley, CA","San Jose, CA","Cupertino, CA","Santa Clara, CA","Pico Rivera, CA","Whittier, CA","Far Rockaway, NY","Secaucus, NJ","Sunnyvale, CA","Menlo Park, CA","Elk Grove Village, IL","Glenview, IL","Maywood, IL","Northfield, IL","Stanford, CA","San Francisco, CA"],"y":[190.0,159.0,159.0,156.0,149.0,138.28947368421052,134.0,133.0909090909091,132.0,132.0,132.0,132.0,130.5625,129.45454545454547,129.0,129.0,129.0,129.0,127.0,126.02521008403362],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555 ...

# %% [markdown]
# ### 3.4. Top 20 Roles with their minimum and maximum salaries

# %%
df=data.groupby('Job Title')[['Max_Salary','Min_Salary']].mean().sort_values(['Max_Salary','Min_Salary'],ascending=False).head(20)

# %%
fig = go.Figure()

fig.add_trace(go.Bar(x=df.index,y=df['Min_Salary'],name='Minimum salary'))
fig.add_trace(go.Bar(x=df.index,y=df['Max_Salary'],name='Maximum Salary'))

fig.update_layout(title='Top 20 Roles with their minimum and maximum salaries',barmode='stack')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="75e3126a-4117-422f-97b4-53e79862439e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("75e3126a-4117-422f-97b4-53e79862439e")) {                    Plotly.newPlot(                        "75e3126a-4117-422f-97b4-53e79862439e",                        [{"name":"Minimum salary","x":["AI Insights Data Analyst","Data Analyst with Data Mapping and API","Senior Data Analyst Studio Finance Engineering","Senior HR Data Analyst","Sr. Data Analyst - Growth & Adoption","Tableau Data Analyst Intern","Business Intelligence Data Modeler\u002fAnalyst","Data Analyst (College & Foundation Reporting)","Data Scientist\u002fAnalyst - Wilbur Labs","Data Studio Analyst","DATA Analyst-Remote","Business Data Analyst - Senior\u002fDirector - Work from Remote","Data and Policy Analyst IV","Loan Data Analyst","Market Data Services Analyst","Apple Media Products (AMP) - Big Data Analyst","Biomedical Data Analyst I - Temporary","Data Analyst I (German)","Finance & Accounting Data Analyst","Senior Data Analyst - Studio Finance Engineering"],"y":[110.0,110.0,110.0,110.0,110.0,110.0,99.0,99.0,99.0,99.0,96.0,93.0,93.0,93.0,93.0,89.0,89.0,89.0,89.0,89.0],"type":"bar"},{"name":"Maximum Salary","x":["AI Insights Data Analyst","Data Analyst with Data Mapping and API","Senior Data Analyst Studio Finance Engineering","Senior HR Data Analyst","Sr. Data Analyst - Growth & Adoption","Tableau Data Analyst Intern","Business Intelligence Data Modeler\u002fAnalyst","Data Analyst (College & Foundation Reporting)","Data Scientist\u002fAnalyst - Wilbur Labs","Data Studio Analyst","DATA Analyst-Remote","Business Data Analyst - Senior\u002fDirector - Work from Remote","Data and Policy Analyst IV","Loan Data Analyst","Market Data Services Analyst","Apple Media Products (AMP) - Big Data Analyst","Biomedical Data Analyst I - Temporary","Data Analyst I (German)","Finance & Accounting Data Analyst","Senior Data Analyst - Studio Finance Engineering"],"y":[190.0,190.0,190.0,190.0,190.0,190.0,178.0,178.0,178.0,178.0,168.5,159.0,159.0,159.0,159.0,151.0,151.0,151.0,151.0,151.0],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921 ...

# %% [markdown]
# ### 3.5. Size of Employees Vs No of Companies

# %%
df=data['Size'].value_counts()

# %%
df=pd.DataFrame(df)
df['employee_size']=df.index

# %%
df.reset_index(inplace=True)
df.drop(['index'],axis=1,inplace=True)

# %%
df=df.rename(columns={"Size": "No_of_companies"})

# %%
plt.figure(figsize=(10,5))
chart = sns.barplot(
    data=df,
    x='employee_size',
    y='No_of_companies',
    palette='Set1'
)
chart=chart.set_xticklabels(
    chart.get_xticklabels(),
    rotation=65,
    horizontalalignment='right',
    fontweight='light',
)

# %% [markdown]
# ### 3.6. Revenue of different sectors

# %%
def filter_revenue(x):
    revenue=0
    if(x== 'Unknown / Non-Applicable' or type(x)==float):
        revenue=0
    elif(('million' in x) and ('billion' not in x)):
        maxRev = x.replace('(USD)','').replace("million",'').replace('$','').strip().split('to')
        if('Less than' in maxRev[0]):
            revenue = float(maxRev[0].replace('Less than','').strip())
        else:
            if(len(maxRev)==2):
                revenue = float(maxRev[1])
            elif(len(maxRev)<2):
                revenue = float(maxRev[0])
    elif(('billion'in x)):
        maxRev = x.replace('(USD)','').replace("billion",'').replace('$','').strip().split('to')
        if('+' in maxRev[0]):
            revenue = float(maxRev[0].replace('+','').strip())*1000
        else:
            if(len(maxRev)==2):
                revenue = float(maxRev[1])*1000
            elif(len(maxRev)<2):
                revenue = float(maxRev[0])*1000
    return revenue

# %%
data['Max_revenue']=data['Revenue'].apply(lambda x: filter_revenue(x))

# %%
df=data.groupby('Sector')[['Max_revenue']].mean().sort_values(['Max_revenue'],ascending=False).head(20)

# %%
df.reset_index(inplace=True)
df
# Out:
#                                 Sector  Max_revenue
# 0                            Insurance  5465.196078
# 1                      Mining & Metals  5000.000000
# 2                  Aerospace & Defense  4884.090909
# 3                   Telecommunications  4778.181818
# 4                              Finance  4653.881657
# 5                               Retail  4447.394737
# 6                        Manufacturing  4382.625000
# 7                                Media  3837.880952
# 8           Transportation & Logistics  3080.000000
# 9            Biotech & Pharmaceuticals  2835.636364
# 10        Oil, Gas, Energy & Utilities  2146.153846
# 11                         Health Care  1728.324503
# 12                           Education  1541.634615
# 13              Information Technology  1274.575439
# 14    Arts, Entertainment & Recreation   928.571429
# 15                  Accounting & Legal   798.418605
# 16                   Business Services   788.543893
# 17                          Non-Profit   524.615385
# 18  Construction, Repair & Maintenance   503.500000
# 19   Restaurants, Bars & Food Services   139.625000

# %%
plt.figure(figsize=(10,5))
chart = sns.barplot(
    data=df,
    x='Sector',
    y='Max_revenue'
)
chart.set_xticklabels(
    chart.get_xticklabels(),
    rotation=65,
    horizontalalignment='right',
    fontweight='light',
)
chart.axes.yaxis.label.set_text("Revenue(Million dollars)")

# %% [markdown]
# ### 3.6. Revenue of different Industries

# %%
df=data.groupby('Industry')[['Max_revenue']].mean().sort_values(['Max_revenue'],ascending=False).head(20)

# %%
df.reset_index(inplace=True)

# %%
plt.figure(figsize=(10,5))
chart = sns.barplot(
    data=df,
    x='Industry',
    y='Max_revenue',
    palette='Set1'
)
chart.set_xticklabels(
    chart.get_xticklabels(),
    rotation=65,
    horizontalalignment='right',
    fontweight='light',
)
chart.axes.yaxis.label.set_text("Revenue(Million dollars)")

# %% [markdown]
# ### 3.7. Word Cloud of job Title

# %%
job_title=data['Job Title'][~pd.isnull(data['Job Title'])]
wordCloud = WordCloud(width=450,height= 300).generate(' '.join(job_title))
plt.figure(figsize=(19,9))
plt.axis('off')
plt.title(data['Job Title'].name,fontsize=20)
plt.imshow(wordCloud)
plt.show()

# %% [markdown]
# ### 3.8. Ratings

# %%
count=data.groupby('Rating')['Company Name'].count()

# %%
df=pd.DataFrame(count).rename(columns={'Company Name': 'Count'}).reset_index()

# %%
df=df.sort_values('Rating',ascending=False).head(20)

# %%
plt.figure(figsize=(10,5))
chart = sns.barplot(
    data=df,
    x='Rating',
    y='Count',
    palette='Set1'
)
chart.set_xticklabels(
    chart.get_xticklabels(),
    rotation=65,
    horizontalalignment='right',
    fontweight='light',
)
chart.axes.yaxis.label.set_text("No. of companies")

# %% [markdown]
# ### 3.9. Industries with their Average minimum and maximum salaries

# %%
df=data.groupby('Industry')[['Min_Salary','Max_Salary']].mean().rename(columns={'Min_Salary':'Avg_min_salary','Max_Salary':'Avg_max_salary'})

# %%
df=df.reset_index()

# %%
df=df.sort_values(['Avg_max_salary','Avg_max_salary'],ascending=False)

# %%
fig = go.Figure()

fig.add_trace(go.Bar(x=df.Industry,y=df['Avg_min_salary'],name='Average Minimum salary'))
fig.add_trace(go.Bar(x=df.Industry,y=df['Avg_max_salary'],name='Average Maximum Salary'))

fig.update_layout(title='Industries with their Average minimum and maximum salaries',barmode='stack')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ea24b262-091e-4e16-b4a2-6a533d12e392" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ea24b262-091e-4e16-b4a2-6a533d12e392")) {                    Plotly.newPlot(                        "ea24b262-091e-4e16-b4a2-6a533d12e392",                        [{"name":"Average Minimum salary","x":["Education Training Services","Gambling","Health Care Products Manufacturing","Transportation Equipment Manufacturing","Electrical & Electronic Manufacturing","Drug & Health Stores","Sports & Recreation","Biotech & Pharmaceuticals","Real Estate","Truck Rental & Leasing","Internet","Utilities","Cable, Internet & Telephone Providers","Computer Hardware & Software","Enterprise Software & Network Solutions","Department, Clothing, & Shoe Stores","Venture Capital & Private Equity","Accounting","Brokerage Services","Consumer Electronics & Appliances Stores","General Repair & Maintenance","Architectural & Engineering Services","Advertising & Marketing","Gas Stations","Lending","Staffing & Outsourcing","Health, Beauty, & Fitness","Motion Picture Production & Distribution","Health Care Services & Hospitals","Automotive Parts & Accessories Stores","News Outlet","Other Retail Stores","Federal Agencies","IT Services","Health Fundraising Organizations","Financial Transaction Processing","Home Centers & Hardware Stores","Building & Personnel Services","Wholesale","Colleges & Universities","Commercial Equipment Repair & Maintenance","Consulting","Logistics & Supply Chain","Publishing","Convenience Stores & Truck Stops","Food & Beverage Stores","Construction","Video Games","Insurance Carriers","Insurance Agencies & Brokerages","Energy","Aerospace & Defense","Beauty & Personal Accessories Stores","Financial Analytics & Research","Transportation Management","Banks & Credit Unions","Investment Banking & Asset Management","Industrial Manufacturing","Consumer Product Rental","Security Services","Social Assistance","Chemical Manufacturing","Telecommunications Services","Food & Beverage Manufacturing","TV Broadcast & Cable Networks","General Merchandise & Superstores","Express Delivery Services","Metals Brokers","Research & Development","State & Regional Agencies","Legal","K-12 Education","Catering & Food Service Contractors","Sporting Goods Stores","Stock Exchanges","Miscellaneous Manufacturing","Municipal Governments","Consumer Products Manufacturing","Pet & Pet Supplies Stores","Hotels, Motels, & Resorts","Membership Organizations","Preschool & Child Care","Casual Restaurants","Vehicle Dealers","Oil & Gas Services","Grocery Stores & Supermarkets","Audiovisual","Trucking"],"y":[69.66666666666667,64.0,69.2,60.333333333333336,60.833333333333336,82.5,69.0,61.36363636363637,57.25,46.0,58.43076923076923,67.0,59.4,57.6036036036036,58.028985507246375,56.6,62.833333333333336,59.15384615384615,51.0,51.0,57.0,52.46153846153846,53.1764705882353,44.666666666666664,50.93333333333333,55.34984520123839,53.84615384615385,54.666666666666664,55.36423841059602,48.5,84.0,55.333333333333336,52.666666666666664,53.30461538461538,51.333333333333336,54.6,48.6,43.0,58.333333333333336,51.35,57.833333333333336,53.369369369369366,54.61538461538461,49.0,44.5,59.5,50.0,50.8,55.38297872340426,49.25,49.285714285714285,51.95454545454545,49.5,50.0,59.0,51.509803921568626,48.52564102564103,53.0,44.0,41.0,48.82608695652174,65.0,45.333333333333336,50.0,50.4,41.666666666666664,41.0,41.0,49.75,44.53333333333333,52.25,54.0,42.0,47.0,54.0,66.5,47.77777777777778,48.9,37.0,57.0,49.25,35.666666666666664,36.2,39.0,36.25,28.333333333333332,24.0,35.0],"type":"bar"},{"name":"Average Maximum Salary","x":["Education Training Services","Gambling","Health Care Products Manufacturing","Transportation Equipment  ...

# %% [markdown]
# ### 3.10. Jobs with Openings

# %%
df=pd.DataFrame(data[data['Easy Apply']==True]['Job Title'].value_counts()).rename(columns={'Job Title':'No_of_openings'})

# %%
df=df.reset_index().rename(columns={'index':'Job Title'})

# %%
df=df.head(10)

# %%
plt.figure(figsize=(10,5))
chart = sns.barplot(
    data=df,
    x='Job Title',
    y='No_of_openings',
    palette='Set1'
)
chart=chart.set_xticklabels(
    chart.get_xticklabels(),
    rotation=65,
    horizontalalignment='right',
    fontweight='light',
)
